# %%
import pandas as pd

# %%
df = pd.read_csv("recipes.csv")
df.head(2)
# Out:
#    Unnamed: 0                      name  prepTimeMinutes  cookTimeMinutes  \
# 0           0  Classic Margherita Pizza               20               15
# 1           1       Vegetarian Stir-Fry               15               20
#
#    servings  caloriesPerServing  reviewCount
# 0         4                 300           98
# 1         3                 250           26

# %%
df = pd.read_csv("recipes.csv", index_col=0)
df.head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
#
#    caloriesPerServing  reviewCount
# 0                 300           98
# 1                 250           26

# %%
df[df["cookTimeMinutes"] < 15]
# Out:
#                          name  prepTimeMinutes  cookTimeMinutes  servings  \
# 2      Chocolate Chip Cookies               15               10        24
# 6     Tomato Basil Bruschetta               15               10         6
# 8               Caprese Salad               10                0         2
# 21                Mango Lassi               10                0         2
# 22           Italian Tiramisu               30                0         6
# 24  Blueberry Banana Smoothie               10                0         1
# 28      Lebanese Falafel Wrap               15               10         2
# 29       Brazilian Caipirinha                5                0         1
#
#     caloriesPerServing  reviewCount
# 2                  150           13
# 6                  120           95
# 8                  200           82
# 21                 180           15
# 22                 350            0
# 24                 220           30
# 28                 400           84
# ...

# %%
df["caloriesPerServing"].min()
# Out:
# np.int64(120)

# %%
df [ df["caloriesPerServing"] ==  df["caloriesPerServing"].min() ]
# Out:
#                       name  prepTimeMinutes  cookTimeMinutes  servings  \
# 6  Tomato Basil Bruschetta               15               10         6
#
#    caloriesPerServing  reviewCount
# 6                 120           95

# %%
df.groupby("servings").agg(['count'])
# Out:
#           name prepTimeMinutes cookTimeMinutes caloriesPerServing reviewCount
#          count           count           count              count       count
# servings
# 1            2               2               2                  2           2
# 2            5               5               5                  5           5
# 3            4               4               4                  4           4
# 4           12              12              12                 12          12
# 5            1               1               1                  1           1
# 6            5               5               5                  5           5
# 24           1               1               1                  1           1

# %%
df.groupby("servings")["name"].agg(['count'])
# Out:
#           count
# servings
# 1             2
# 2             5
# 3             4
# 4            12
# 5             1
# 6             5
# 24            1

# %%
df[df["servings"] == 24]
# Out:
#                      name  prepTimeMinutes  cookTimeMinutes  servings  \
# 2  Chocolate Chip Cookies               15               10        24
#
#    caloriesPerServing  reviewCount
# 2                 150           13

# %%
retete_noi =   {"name" : ["Tiramisu", "Gogosi"], "prepTimeMinutes":[25, 20], "cookTimeMinutes" :[90, 40], 	"servings" : [12, 40], "caloriesPerServing" : [500, 600], "reviewCount" :[3, 5]}

# %%
df_noi = pd.DataFrame(retete_noi)
df_noi
# Out:
#        name  prepTimeMinutes  cookTimeMinutes  servings  caloriesPerServing  \
# 0  Tiramisu               25               90        12                 500
# 1    Gogosi               20               40        40                 600
#
#    reviewCount
# 0            3
# 1            5

# %%
result_df = pd.concat([df, df_noi])
result_df.head()
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
# 2    Chocolate Chip Cookies               15               10        24
# 3     Chicken Alfredo Pasta               15               20         4
# 4       Mango Salsa Chicken               15               25         3
#
#    caloriesPerServing  reviewCount
# 0                 300           98
# 1                 250           26
# 2                 150           13
# 3                 500           82
# 4                 380           63
