# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
imagine = mpimg.imread("patrat.png")

# %%
figure, axis = plt.subplots()
print(figure)
# Out:
# Figure(640x480)

# %%
figure, axes = plt.subplots()
print(figure)

imagine = mpimg.imread("patrat.png")
axes.imshow(imagine)
plt.show();
# Out:
# Figure(640x480)
