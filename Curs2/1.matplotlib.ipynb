# %% [markdown]
# # pip install matplotlib
# daca nu este instalat

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([0, 0], [1, 2]);

# %%
plt.scatter([0, 0, 2], [1, 2, 3]);

# %%
plt.plot([0, 0, 2], [1, 2, 3]);

# %%
plt.plot([0, 0, 2], [1, 2, 2]);

# %%
plt.plot([0, 0, 2, 2], [1, 2, 2, 1]);

# %%
plt.plot([0, 0, 2, 2, 0], [1, 2, 2, 1, 1]);

# %%
plt.plot([0, 0, 2, 2, 0], [1, 2, 2, 1, 1])
plt.savefig("patrat.png")
