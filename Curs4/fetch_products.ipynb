# %%
import requests
import json

# %%
URL  = 'https://dummyjson.com/products/'

LIMIT = 1

# %%
response = requests.get(URL, params={"limit":LIMIT})
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'products': [{'id': 1,
#    'title': 'Essence Mascara Lash Princess',
#    'description': 'The Essence Mascara Lash Princess is a popular mascara known for its volumizing and lengthening effects. Achieve dramatic lashes with this long-lasting and cruelty-free formula.',
#    'category': 'beauty',
#    'price': 9.99,
#    'discountPercentage': 10.48,
#    'rating': 2.56,
#    'stock': 99,
#    'tags': ['beauty', 'mascara'],
#    'brand': 'Essence',
#    'sku': 'BEA-ESS-ESS-001',
#    'weight': 4,
#    'dimensions': {'width': 15.14, 'height': 13.08, 'depth': 22.99},
#    'warrantyInformation': '1 week warranty',
#    'shippingInformation': 'Ships in 3-5 business days',
#    'availabilityStatus': 'In Stock',
#    'reviews': [{'rating': 3,
#      'comment': 'Would not recommend!',
#      'date': '2025-04-30T09:41:02.053Z',
#      'reviewerName': 'Eleanor Collins',
#      'reviewerEmail': 'eleanor.collins@x.dummyjson.com'},
#     {'rating': 4,
#      'comment': 'Very satisfied!',
# ...

# %%
response = requests.get("https://cdn.dummyjson.com/product-images/beauty/essence-mascara-lash-princess/thumbnail.webp")

# %%
response.content
# Out:
# b'RIFFx\'\x00\x00WEBPVP8X\n\x00\x00\x00\x10\x00\x00\x00+\x01\x00+\x01\x00ALPH,\x17\x00\x00\x01\x19\x86m\xdbF\x82\x94\xb6\xf7$\xdd\x7f\xe1o\x85\x88\xfeO\x00\xcb\x88\x88\xc5\xa3\n\x99\xd4\xca\xedU\x1e,!\xa5\x1c\xca7\x99\x95\x8fB\xef\xbd?\x8fr\x14\xb4m#%\xe1\xcfz\xbb\x07BDL\x00\xd3V\xfb\xcdz\xd1W\xcd\xf2\x92i\x1a\x049\x92$ER\xb5\xfe\x02\xafmS-s\xb9\xdd\xef"&\xc0\x81$IJT\x03\xb36=8\x9c~\xc0\xd3\xb5m\x86\xa4\xed\xffw\x1cQU\x8d\xfb\xb1m\xdb\xb6\x9f\xf1\xf3J\x8c!\xc7\xcf\xecy\t\xb6m\xdb\xe6m\xb3U\xc8\x8c8\xd6\xaa8\xcf32j\xad\xaeqD@\x90$\xb9ms$ \x84#8\xb7\x07J\x8e\x1f\xf0\x80m\x9b\xda\xb6\xda\xb6\x9d\xd7H\xb2\x93\x18b\xbbI\xbb\x92\xa6\xdc\xde\x8b\xca\xdc\xc5\xcc\xccL733333333\xf3}/,3\xa6+L\x8e#\xcd\xb5m\x96\x9cZ3s\x8ftsD@\x94$\xa9\x8a\xd4jk\xb3\x0c1\x0c>\x80\xd3\xfb\x80\x18\xfeT\xf6\xef?\xffo\x10\x8eHO\x10\x81\x04\xa5%\x10x\xca\xc5ii\xa5z\x96~;X\n7\x15\x1d\x1cl\xfe\x88\xda\xbd\x97\xfb\x9c\x92\xe4{\x89\xbf\xf1\xc3\xcbn\xbb1\x05\xa1\xed1w>:\xcb8\xefc\xef>7\xf5\x18\x08\xbe\xea\xdd\xf3\xbf=$\xb8
# ...
